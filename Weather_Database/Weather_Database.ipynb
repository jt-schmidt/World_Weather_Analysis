# %%
# Deliverable 1:  Retrieve Weather Data
#Retrieve all of the following information from the API call: (15 pt)

    #Latitude and longitude
    #Maximum temperature
    #Percent humidity
    #Percent cloudiness
    #Wind speed
    #Weather description (for example, clouds, fog, light rain, clear sky)
    #Add the weather data to a new DataFrame (5 pt)

#Export the DataFrame as WeatherPy_Database.csv into the Weather_Database folder (5 pt)

#Be sure to double-check that you have the following in the Weather_Database folder:

    #The Weather_Database.ipynb file
    #The WeatherPy_Database.csv file

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
## STEP 3 Create a new set of 2,000 random latitudes and longitudes.

# 6.1.4 Generate Random Latitudes and Longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
## STEP 3 Create a new set of 2,000 random latitudes and longitudes.

# 6.1.4 Generate Random Latitudes and Longitudes
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
## STEP 4 Get the nearest city using the citipy module.

# 6.1.5 Generate Random World Cities
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
## STEP 4 Get the nearest city using the citipy module.

# 6.1.5 Generate Random World Cities
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
## STEP 4 Get the nearest city using the citipy module.

# 6.1.5 Generate Random World Cities
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# avarua ck
# port alfred za
# busselton au
# mackenzie ca
# atuona pf
# punta arenas cl
# sochi ru
# punta arenas cl
# bethel us
# jamestown sh
# souillac mu
# kapaa us
# east london za
# naliya in
# dawlatabad af
# karamea nz
# jurado co
# gisenyi rw
# taolanaro mg
# clyde river ca
# sitka us
# albany au
# seoul kr
# tateyama jp
# vaitupu wf
# samarai pg
# krasnoselkup ru
# ushuaia ar
# hobart au
# atuona pf
# mahebourg mu
# mehamn no
# butaritari ki
# bluff nz
# bluff nz
# sola vu
# dikson ru
# avarua ck
# chore py
# bluff nz
# codrington ag
# boyolangu id
# gravdal no
# sayat tm
# severo-kurilsk ru
# mahajanga mg
# javanrud ir
# anori br
# new norfolk au
# rikitea pf
# dondo mz
# hualmay pe
# saleaula ws
# hobart au
# port alfred za
# paso de carrasco uy
# upernavik gl
# jamestown sh
# vydrino ru
# tawkar sd
# carnarvon au
# ponta do sol pt
# urengoy ru
# isangel vu
# bosaso so
# ushuaia ar
# puerto escondido mx
# albany au
# richards bay za
# hithadhoo mv
# taolanaro mg
# ...

# %%
## STEP 5 & 6 Perform an API call with OpenWeatherMap
## Retrieve following info:
    ## Latitude and Longitude
    ## Maximum temperature
    ## Percent humidity
    ## Percent cloudiness
    ## Wind speed
    ## Weather description (for example, clouds, fog, light rain, clear sky)
    
# 6.2.3 Make an API call
# Import the requests library.
import requests
import json
from datetime import datetime

# Import the API key.
from config_w import weather_api_key

# %%
## STEP 5 & 6 Perform an API call with OpenWeatherMap
## Confirm good response for example city

# 6.2.3 Make an API call
# Create an endpoint URL for a city.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Use Boston as test case to confirm correct data retrieval and dataframe creation.
city_url = url + "&q=" + "Boston"
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
## STEP 5 & 6 Perform an API call with OpenWeatherMap
# confirm json structure

# 6.2.4 Make a Request for Data to an API
# Get the text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 75.34,
#   'feels_like': 69.44,
#   'temp_min': 72,
#   'temp_max': 78.01,
#   'pressure': 1020,
#   'humidity': 39},
#  'visibility': 10000,
#  'wind': {'speed': 10, 'deg': 13, 'gust': 24},
#  'clouds': {'all': 0},
#  'dt': 1599325304,
#  'sys': {'type': 3,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1599300858,
#   'sunset': 1599347498},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
## STEP 5 & 6 Perform an API call with OpenWeatherMap
# Parse json into list and insert to dataframe for 1 city to confirm works.
city_data = []

city_weather = requests.get(city_url).json()
city_lat = city_weather["coord"]["lat"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_description = city_weather['weather'][0]['description']
# Convert the date to ISO standard.
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

# Append the city information into city_data list.
city_data.append({"City": city.title(),
                  "Weather Description": city_description,
                  "Lat": city_lat,
                  "Lng": city_lng,
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Country": city_country,
                  "Date": city_date})

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#    City Weather Description    Lat    Lng  Max Temp  Humidity  Cloudiness  \
# 0  Lebu           clear sky  42.36 -71.06     78.01        39           0
#
#    Wind Speed Country                 Date
# 0          10      US  2020-09-05 17:01:44

# %%
## STEP 5 & 6 Perform an API call with OpenWeatherMap
## Retrieve following info:
    ## Latitude and Longitude
    ## Maximum temperature
    ## Percent humidity
    ## Percent cloudiness
    ## Wind speed
    ## Weather description (for example, clouds, fog, light rain, clear sky)

# 6.2.6 Get the City Weather Data
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
## STEP 5 & 6 Retrieve following info:
    ## Latitude and Longitude
    ## Maximum temperature
    ## Percent humidity
    ## Percent cloudiness
    ## Wind speed
    ## Weather description (for example, clouds, fog, light rain, clear sky)

# 6.2.6 Get the City Weather Data
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Current Description": city_description,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | mackenzie
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | sochi
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | naliya
# Processing Record 14 of Set 1 | dawlatabad
# Processing Record 15 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 1 | jurado
# Processing Record 17 of Set 1 | gisenyi
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | seoul
# ...

# %%
## STEP 7 Add the data to a new DataFrame (city_data_df)

# 6.2.7 Create a DataFrame of City Weather Data

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Current Description    Lat     Lng  Max Temp  Humidity  \
# 0        Avarua     overcast clouds -21.21 -159.78     71.60        88
# 1   Port Alfred       broken clouds -33.59   26.89     63.64        74
# 2     Busselton       broken clouds -33.65  115.33     63.00        71
# 3     Mackenzie       broken clouds  55.30 -123.17     53.60        93
# 4        Atuona          few clouds  -9.80 -139.03     79.48        73
# 5  Punta Arenas    scattered clouds -53.15  -70.92     39.20        86
# 6         Sochi          light rain  43.60   39.73     77.00        83
# 7        Bethel           clear sky  41.37  -73.41     75.99        35
# 8     Jamestown       broken clouds  42.10  -79.24     66.99        55
# 9      Souillac         shower rain -20.52   57.52     69.80        83
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100        9.17      CK  2020-09-05 17:01:45
# 1          84        9.78      ZA  2020-09-05 17:01:45
# ...

# %%
## STEP 7 Add the data to a new DataFrame (city_data_df)
# Re-order columns

column_names = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description","Date"]

city_data_df = city_data_df.reindex(columns=column_names)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Avarua      CK -21.21 -159.78     71.60        88         100
# 1   Port Alfred      ZA -33.59   26.89     63.64        74          84
# 2     Busselton      AU -33.65  115.33     63.00        71          79
# 3     Mackenzie      CA  55.30 -123.17     53.60        93          75
# 4        Atuona      PF  -9.80 -139.03     79.48        73          15
# 5  Punta Arenas      CL -53.15  -70.92     39.20        86          40
# 6         Sochi      RU  43.60   39.73     77.00        83          90
# 7        Bethel      US  41.37  -73.41     75.99        35           1
# 8     Jamestown      US  42.10  -79.24     66.99        55          75
# 9      Souillac      MU -20.52   57.52     69.80        83          75
#
#    Wind Speed Current Description                 Date
# 0        9.17     overcast clouds  2020-09-05 17:01:45
# 1        9.78       broken clouds  2020-09-05 17:01:45
# ...

# %%
## STEP 8 Export the DataFrame as a CSV file and save to folder

# 6.2.7 Create a DataFrame of City Weather Data
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
